# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as anime
import matplotlib as mpl
import numpy as np

# %%
plt.figure(figsize=(20, 12))
df = pd.read_csv("cmake-build-debug/output.csv")
hi = plt.hist(df[:], bins=25, width = 0.6)
plt.ylabel("Numbers of balls per bin")
plt.xlabel("Velocity")
plt.show()
